# %%
import requests


url = "https://www.ariel-datachallenge.space/api/score/calculate/"



data = {
    "team_no": "0",
    "team_name": "ESATest",
    "secret_key": "esa_test",
}


files = {
    "file": ("dummy_ld_file_allones.csv", open("dummy_ld_file_allones.csv", "rb"), "text/csv"),
}


response = requests.post(url, data=data, files=files)

print(f"Status Code: {response.status_code}")
response_json = response.json()
print(f"Response JSON: {response_json}")
#print(f"Hello Team '{data['team_name']}' you have a a score of {response_json['score']}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 16
#       4 url = "https://www.ariel-datachallenge.space/api/score/calculate/"
#       8 data = {
#       9     "team_no": "0",
#      10     "team_name": "ESATest",
#      11     "secret_key": "esa_test",
#      12 }
#      15 files = {
# ---> 16     "file": ("dummy_ld_file_allones.csv", open("dummy_ld_file_allones.csv", "rb"), "text/csv"),
#      17 }
#      20 response = requests.post(url, data=data, files=files)
#      22 print(f"Status Code: {response.status_code}")
#
# File /Software/users/modules/9/software/anaconda3/2024.02/lib/python3.11/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
# ...

# %%
secret_codes = {
    "Gliese" : "Shobolinsky",
    "Kepler" : "Zdzblo Szczebrzeszyn",
    "Curiel" : "ExoLoop",
    "Keck" : "ROSPIN",
    "Nobel": "51-Pegasi-b",
    "Cancri": "55-Cancri-e",
    "4LYs": "Prox-Cent-b",
    "JWST": "WASP-39-b",
    "2006": "CoRoT-7-b",
    "Gliese": "GJ-1252-b",
}

for value in secret_codes.values():
    print(value)
